# %%
# Databricks notebook source
# MAGIC %md
# MAGIC # ShopStream event generator
# MAGIC Simulates the live order feed. Every few seconds it drops a small JSON file
# MAGIC of order events into the `events` Volume — exactly how many real systems land
# MAGIC data (Kinesis Firehose, Kafka sink connectors, app exports all write files).
# MAGIC Auto Loader in the next notebook picks these up as a stream.
# MAGIC
# MAGIC Run this notebook, leave it running, and switch to the streaming notebook.

# COMMAND ----------

import json
import random
import time
import uuid
from datetime import datetime, timezone

CATALOG = "shop_stream"
SCHEMA = "core"
EVENTS_PATH = f"/Volumes/{CATALOG}/{SCHEMA}/events/orders_stream"

#dbutils.fs.mkdirs(EVENTS_PATH)

random.seed()  # live feed, so genuinely random

PRODUCT_IDS = [f"P{i:04d}" for i in range(1, 198)]
CUSTOMER_IDS = [f"C{i:05d}" for i in range(1, 1001)]
STATUSES = ["completed"] * 9 + ["cancelled"]

BATCHES = 60          # how many files to drop
EVENTS_PER_BATCH = 25 # order lines per file
SLEEP_SECONDS = 5     # gap between files

for batch in range(BATCHES):
    events = []
    for _ in range(EVENTS_PER_BATCH):
        events.append({
            "event_id": str(uuid.uuid4()),
            "order_id": f"S{random.randint(1, 999999):06d}",
            "customer_id": random.choice(CUSTOMER_IDS),
            "product_id": random.choice(PRODUCT_IDS),
            "quantity": random.choices([1, 2, 3], weights=[75, 18, 7])[0],
            "unit_price": round(random.uniform(9, 400), 2),
            "status": random.choice(STATUSES),
            "event_ts": datetime.now(timezone.utc).isoformat(),
        })
    fname = f"{EVENTS_PATH}/events_{int(time.time())}_{batch:03d}.json"
    dbutils.fs.put(fname, "\n".join(json.dumps(e) for e in events), overwrite=True)
    print(f"[{batch + 1}/{BATCHES}] wrote {EVENTS_PER_BATCH} events -> {fname}")
    time.sleep(SLEEP_SECONDS)

print("Done. The feed has stopped — re-run this cell to send more events.")
# Out:
# Wrote 5791 bytes.
# [1/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515642_000.json
# Wrote 5791 bytes.
# [2/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515671_001.json
# Wrote 5789 bytes.
# [3/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515677_002.json
# Wrote 5794 bytes.
# [4/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515683_003.json
# Wrote 5791 bytes.
# [5/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515688_004.json
# Wrote 5793 bytes.
# [6/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515694_005.json
# Wrote 5790 bytes.
# [7/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515700_006.json
# Wrote 5787 bytes.
# [8/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515705_007.json
# Wrote 5790 bytes.
# [9/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515711_008.json
# Wrote 5793 bytes.
# [10/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515716_009.json
# Wrote 5789 bytes.
# [11/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515722_010.json
# Wrote 5789 bytes.
# [12/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515727_011.json
# Wrote 5791 bytes.
# [13/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515733_012.json
# Wrote 5790 bytes.
# [14/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515739_013.json
# Wrote 5790 bytes.
# [15/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515744_014.json
# Wrote 5789 bytes.
# [16/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515750_015.json
# Wrote 5792 bytes.
# [17/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515755_016.json
# Wrote 5789 bytes.
# [18/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515761_017.json
# Wrote 5793 bytes.
# [19/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515766_018.json
# Wrote 5790 bytes.
# [20/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515772_019.json
# Wrote 5797 bytes.
# [21/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515777_020.json
# Wrote 5788 bytes.
# [22/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515783_021.json
# Wrote 5793 bytes.
# [23/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515788_022.json
# Wrote 5790 bytes.
# [24/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515794_023.json
# Wrote 5791 bytes.
# [25/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515799_024.json
# Wrote 5792 bytes.
# [26/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515805_025.json
# Wrote 5790 bytes.
# [27/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515810_026.json
# Wrote 5796 bytes.
# [28/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515816_027.json
# Wrote 5791 bytes.
# [29/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515822_028.json
# Wrote 5789 bytes.
# [30/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515827_029.json
# Wrote 5785 bytes.
# [31/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515833_030.json
# Wrote 5791 bytes.
# [32/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515838_031.json
# Wrote 5791 bytes.
# [33/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515844_032.json
# Wrote 5792 bytes.
# [34/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515849_033.json
# Wrote 5789 bytes.
# [35/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515855_034.json
# Wrote 5792 bytes.
# [36/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515860_035.json
# Wrote 5797 bytes.
# [37/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515866_036.json
# Wrote 5788 bytes.
# [38/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515871_037.json
# Wrote 5791 bytes.
# [39/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515877_038.json
# Wrote 5791 bytes.
# [40/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515882_039.json
# Wrote 5794 bytes.
# [41/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515887_040.json
# Wrote 5789 bytes.
# [42/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515893_041.json
# Wrote 5789 bytes.
# [43/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515899_042.json
# Wrote 5790 bytes.
# [44/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515904_043.json
# Wrote 5790 bytes.
# [45/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515910_044.json
# Wrote 5788 bytes.
# [46/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515915_045.json
# Wrote 5790 bytes.
# [47/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515921_046.json
# Wrote 5791 bytes.
# [48/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515926_047.json
# Wrote 5793 bytes.
# [49/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515932_048.json
# Wrote 5790 bytes.
# [50/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515937_049.json
# Wrote 5785 bytes.
# [51/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515943_050.json
# Wrote 5787 bytes.
# [52/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515948_051.json
# Wrote 5789 bytes.
# [53/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515954_052.json
# Wrote 5790 bytes.
# [54/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515959_053.json
# Wrote 5792 bytes.
# [55/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515965_054.json
# Wrote 5789 bytes.
# [56/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515970_055.json
# Wrote 5789 bytes.
# [57/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515976_056.json
# Wrote 5790 bytes.
# [58/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515981_057.json
# Wrote 5791 bytes.
# [59/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515987_058.json
# Wrote 5789 bytes.
# [60/60] wrote 25 events -> /Volumes/shop_stream/core/events/orders_stream/events_1789515992_059.json
# Done. The feed has stopped — re-run this cell to send more events.
